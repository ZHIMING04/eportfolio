# %% [markdown]
# #Data Mining Assignment 1

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configuring styles
sns.set_style("darkgrid")
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
#load dataset
df = pd.read_csv('https://docs.google.com/spreadsheets/d/1uiZknEeXahbUJAL852RUUemSZnKR0Q0_7p08kwuHEH8/export?format=csv')
df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
# Data Cleaning
missing_value = df.isnull().sum()
missing_value
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
# df['artists'].fillna(df['artists'].mode()[0], inplace=True)
# df['album_name'].fillna(df['album_name'].mode()[0], inplace=True)
# df['track_name'].fillna(df['track_name'].mode()[0], inplace=True)
# df.isnull().sum()

# %%
# Deleting the id and Unnamed column
df = df.drop(['Unnamed: 0', 'track_id'], axis=1)
df
# Out:
#                        artists  \
# 0                  Gen Hoshino
# 1                 Ben Woodward
# 2       Ingrid Michaelson;ZAYN
# 3                 Kina Grannis
# 4             Chord Overstreet
# ...                        ...
# 113995           Rainy Lullaby
# 113996           Rainy Lullaby
# 113997           Cesária Evora
# 113998        Michael W. Smith
# 113999           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# ...

# %%
# Get Basic information of the data mean, std, quatile and min, max values
df.describe().T
# Out:
#                      count           mean            std     min  \
# popularity        114000.0      33.238535      22.305078   0.000
# duration_ms       114000.0  228029.153114  107297.712645   0.000
# danceability      114000.0       0.566800       0.173542   0.000
# energy            114000.0       0.641383       0.251529   0.000
# key               114000.0       5.309140       3.559987   0.000
# loudness          114000.0      -8.258960       5.029337 -49.531
# mode              114000.0       0.637553       0.480709   0.000
# speechiness       114000.0       0.084652       0.105732   0.000
# acousticness      114000.0       0.314910       0.332523   0.000
# instrumentalness  114000.0       0.156050       0.309555   0.000
# liveness          114000.0       0.213553       0.190378   0.000
# valence           114000.0       0.474068       0.259261   0.000
# tempo             114000.0     122.147837      29.978197   0.000
# ...

# %%
# Types of Genre
df['track_genre'].value_counts()
# Out:
# track_genre
# acoustic       1000
# afrobeat       1000
# alt-rock       1000
# alternative    1000
# ambient        1000
#                ...
# techno         1000
# trance         1000
# trip-hop       1000
# turkish        1000
# world-music    1000
# Name: count, Length: 114, dtype: int64

# %%
# Slice data to continuous data only
df_sliced = df.iloc[:, list(range(3, 5)) + list(range(6, df.shape[1] - 1))]
# df_sliced

# %%
# Calculate Correlation
corr = df_sliced.corr()

# %%
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['figure.figsize'] = (18, 9)
sns.heatmap(corr, cmap = 'Blues', annot = True, fmt = '.2f');

# %%
# Get hightest correlation
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(df_sliced, 10))
# Out:
# Top Absolute Correlations
# energy            loudness            0.761690
#                   acousticness        0.733906
# loudness          acousticness        0.589803
# danceability      valence             0.477341
# loudness          instrumentalness    0.433477
# instrumentalness  valence             0.324312
# loudness          valence             0.279848
# danceability      loudness            0.259077
# energy            valence             0.258934
#                   tempo               0.247851
# dtype: float64

# %%
# Insight 1
plt.figure(figsize=(16, 9))

# Filter the data to only include the top 5 genres to reduce size
top_genres = df['track_genre'].value_counts().nlargest(5).index
df_top_genres = df[df['track_genre'].isin(top_genres)]

# Scatter plot of Energy vs. Loudness
sns.scatterplot(data = df_top_genres,
                x = 'energy',
                y = 'loudness',
                hue = 'track_genre');

plt.title('Energy vs Loudness (Top 5 Genres)')
plt.show()

# %% [markdown]
# Based on previous cell that determines the track genre, can we notice that there are 114 genres and each of them have about 1000 tracks. Thus, the top 5 genres obtained from the previous cell may not be accurate.

# %% [markdown]
# # Insight 1
# Based on the scatterplot, we can generally conclude that as the loudness of the music increases, the energy increases.

# %%
# Insight 2
# Group by genre and calculate average popularity
genre_popularity = df.groupby("track_genre")["popularity"].mean()
genre_popularity = genre_popularity.sort_values(ascending=False)

print("Top 10 Popular Genre")
print(genre_popularity.head(10))
# Out:
# Top 10 Popular Genre
# track_genre
# pop-film     59.283
# k-pop        56.896
# chill        53.651
# sad          52.379
# grunge       49.594
# indian       49.539
# anime        48.772
# emo          48.128
# sertanejo    47.866
# pop          47.576
# Name: popularity, dtype: float64

# %% [markdown]
# # Insight 2
# The average popularity is calculated for each genre. It can be seen that Pop-film, K-pop and chill music are more popular on average.

# %% [markdown]
# # Insight 3
# Songs with higher acousticness are generally less energetic, which may impact their suitability for inclusion in workout or party playlists, but make them more favorable for relaxation or study playlists.

# %%
# visualize the negative relationship between acousticness and energy, tuse scatter plot

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='acousticness', y='energy')
plt.title('Acousticness vs. Energy')
plt.xlabel('Acousticness')
plt.ylabel('Energy')
plt.show()

# %% [markdown]
# 🔍 **Insight from Data Analysis**
#
#
# *   The correlation coefficient between acousticness and energy is approximately -0.73, indicating a strong inverse relationship.
# *   The scatter plot confirms that high-acoustic songs typically have low energy levels.
#
#
# 💡 **Business Insight**
#
#
# *   High-acoustic, low-energy tracks are better suited for playlists like:
#
#
# 1.   *Sleep*
# 2.   *Chill*
# 3.   *Study Vibes*
# 4.   *Focus*
#
# *   Low-acoustic, high-energy tracks are ideal for:
#
#
# 1.   *Workout*
# 2.   *Party*
# 3.   *Upbeat Pop*
